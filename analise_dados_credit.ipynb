# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlosilva01/banco_credit/blob/main/analise_dados_credit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Metadados do DataFrame:
#
# O conjunto de dados credit contém informações sobre pagamentos, fatores demográficos, dados de crédito, histórico de pagamentos e extratos de contas de clientes de cartão de crédito em Taiwan de abril de 2005 a setembro de 2005.
#
# O DataFrame contém 25 variáveis:
#
# ID: ID de cada cliente.
#
# LIMIT_BAL: Valor do crédito concedido em NT (New Taiwan) dólar (inclui crédito individual e familiar/complementar).
#
# SEXO: Gênero (1=masculino, 2=feminino).
#
# EDUCAÇÃO: (1 = pós-graduação, 2 = universidade, 3 = ensino médio, 4 = outros, 5 = desconhecido, 6 = desconhecido).
#
# CASAMENTO: Estado civil (1=casado, 2=solteiro, 3=outros).
#
# IDADE: Idade em anos.
#
# PAY_0: Status de pagamento em setembro de 2005 .(-1=pagamento devido, 1=atraso de pagamento por um mês, 2=atraso de pagamento por dois meses, … 8=atraso de pagamento por oito meses, 9=atraso de pagamento por nove meses e acima).
#
# PAY_2: Status de reembolso em agosto de 2005 (escala igual à acima).
#
# PAY_3: Status de reembolso em julho de 2005 (escala igual à acima).
#
# PAY_4: Status de reembolso em junho de 2005 (escala igual à acima).
#
# PAY_5: Status de reembolso em maio de 2005 (escala igual à acima).
#
# PAY_6: Status de reembolso em abril de 2005 (escala igual à acima).
#
# BILL_AMT1: Valor do extrato da conta em setembro de 2005 (dólar NT).
#
# BILL_AMT2: Valor do extrato da conta em agosto de 2005 (dólar NT).
#
# BILL_AMT3: Valor do extrato da conta em julho de 2005 (dólar NT).
#
# BILL_AMT4: Valor do extrato da conta em junho de 2005 (dólar NT).
#
# BILL_AMT5: Valor do extrato da conta em maio de 2005 (dólar NT).
#
# BILL_AMT6: Valor do extrato da conta em abril de 2005 (dólar NT).
#
# PAY_AMT1: Valor do pagamento anterior em setembro de 2005 (dólar NT).
#
# PAY_AMT2: Valor do pagamento anterior em agosto de 2005 (dólar NT).
#
# PAY_AMT3: Valor do pagamento anterior em julho de 2005 (dólar NT).
#
# PAY_AMT4: Valor do pagamento anterior em junho de 2005 (dólar NT).
#
# PAY_AMT5: Valor do pagamento anterior em maio de 2005 (dólar NT).
#
# PAY_AMT6: Valor do pagamento anterior em abril de 2005 (dólar NT).
#
# default.payment.next.month: Pagamento padrão (1=sim, 0=não).

# %% [markdown]
# # Nova seção

# %% [markdown]
# 1° Passo
#
# * Leitura e entendimento de metadados

# %%
import numpy as np
import pandas as pd

# %%
credit = pd.read_csv('/content/credit_card_clients.csv')
credit
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %% [markdown]
# EXTRAINDO INFORMAÇÕES DO DATASET

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
credit.shape
# Out:
# (30000, 25)

# %%
# Mostra as 5 primeiras linhas do dataset
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
#Mostra as 5 últias linhas do dataset
credit.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
# Renomeando colunas no Dataset
# É sempre bom criar uma nova variável para não perder o dataset original
# Dentro dos parenteses, coloca se quer alterar coluna ou linhas e abre chaves e valores
credit_renamed = credit.rename(columns ={'LIMIT_BAL': 'limite_credito',
                                         'SEX':'sexo',
                                         'EDUCATION': 'nivel_escolaridade',
                                         'MARRIAGE': 'estado_civil',
                                         'AGE': 'idade',
                                         'PAY_0': 'status_pag_set_2005',
                                         'PAY_2': 'status_pag_ago_2005',
                                         'PAY_3': 'status_pag_jul_2005',
                                         'PAY_4': 'status_pag_jun_2005',
                                         'PAY_5': 'status_pag_maio_2005',
                                         'PAY_6': 'status_pag_abr_2005',
                                         'BILL_AMT1': 'extrato_set_2005',
                                         'BILL_AMT2': 'extrato_ago_2005',
                                         'BILL_AMT3': 'extrato_jul_2005',
                                         'BILL_AMT4': 'extrato_jun_2005',
                                         'BILL_AMT5': 'extrato_maio_2005',
                                         'BILL_AMT6': 'extrato_abr_2005',
                                         'PAY_AMT1': 'valor_pag_set_2005',
                                         'PAY_AMT2': 'valor_pag_ago_2005',
                                         'PAY_AMT3': 'valor_pag_jul_2005',
                                         'PAY_AMT4': 'valor_pag_jun_2005',
                                         'PAY_AMT5': 'valor_pag_maio_2005',
                                         'PAY_AMT6': 'valor_pag_abr_2005',
    
}

)

# %%
credit_renamed
# Out:
#           ID  limite_credito  sexo  nivel_escolaridade  estado_civil  idade  \
# 0          1           20000     2                   2             1     24
# 1          2          120000     2                   2             2     26
# 2          3           90000     2                   2             2     34
# 3          4           50000     2                   2             1     37
# 4          5           50000     1                   2             1     57
# ...      ...             ...   ...                 ...           ...    ...
# 29995  29996          220000     1                   3             1     39
# 29996  29997          150000     1                   3             2     43
# 29997  29998           30000     1                   2             2     37
# 29998  29999           80000     1                   3             1     41
# 29999  30000           50000     1                   2             1     46
#
# ...

# %%
# Excluir uma coluna
# utiliza-se axis. 0 é ara excluir linhas e 1 exclui colunas

credit_renamed.drop(['default payment next month'], axis=1)
# Out:
#           ID  limite_credito  sexo  nivel_escolaridade  estado_civil  idade  \
# 0          1           20000     2                   2             1     24
# 1          2          120000     2                   2             2     26
# 2          3           90000     2                   2             2     34
# 3          4           50000     2                   2             1     37
# 4          5           50000     1                   2             1     57
# ...      ...             ...   ...                 ...           ...    ...
# 29995  29996          220000     1                   3             1     39
# 29996  29997          150000     1                   3             2     43
# 29997  29998           30000     1                   2             2     37
# 29998  29999           80000     1                   3             1     41
# 29999  30000           50000     1                   2             1     46
#
# ...

# %%
# Escrevendo dados tabulares
# usa-se a váriavel.to para salvar o arquivo.

credit_renamed.to_excel('Clientes_renemad.xlsx')

# %% [markdown]
# 2° Passo
#
# * ENTENDIMENTO DA ESTRUTURA DO DATASET

# %%
#Acessando os rótulos das linhas
#index

credit_renamed.index #Step mostra como o index aparece na tabela (id)
# Out:
# RangeIndex(start=0, stop=30000, step=1)

# %%
#Acessando os Rótulos das colunas, ficando mais fácil saber os nomes das colunas
#Alguns Datasets são grandes e não aparecem todos os nomes das colunas

credit_renamed.columns
# Out:
# Index(['ID', 'limite_credito', 'sexo', 'nivel_escolaridade', 'estado_civil',
#        'idade', 'status_pag_set_2005', 'status_pag_ago_2005',
#        'status_pag_jul_2005', 'status_pag_jun_2005', 'status_pag_maio_2005',
#        'status_pag_abr_2005', 'extrato_set_2005', 'extrato_ago_2005',
#        'extrato_jul_2005', 'extrato_jun_2005', 'extrato_maio_2005',
#        'extrato_abr_2005', 'valor_pag_set_2005', 'valor_pag_ago_2005',
#        'valor_pag_jul_2005', 'valor_pag_jun_2005', 'valor_pag_maio_2005',
#        'valor_pag_abr_2005', 'default payment next month'],
#       dtype='object')

# %%
#Outra forma de visualizar as colunas é
#Tanto variável.columns quanto variável.keys mostrarão o mesmo resultado

credit_renamed.keys()
# Out:
# Index(['ID', 'limite_credito', 'sexo', 'nivel_escolaridade', 'estado_civil',
#        'idade', 'status_pag_set_2005', 'status_pag_ago_2005',
#        'status_pag_jul_2005', 'status_pag_jun_2005', 'status_pag_maio_2005',
#        'status_pag_abr_2005', 'extrato_set_2005', 'extrato_ago_2005',
#        'extrato_jul_2005', 'extrato_jun_2005', 'extrato_maio_2005',
#        'extrato_abr_2005', 'valor_pag_set_2005', 'valor_pag_ago_2005',
#        'valor_pag_jul_2005', 'valor_pag_jun_2005', 'valor_pag_maio_2005',
#        'valor_pag_abr_2005', 'default payment next month'],
#       dtype='object')

# %%
#Identificando todos os valores dentro do Dataset, em formato de array

credit_renamed.values
# Out:
# array([[     1,  20000,      2, ...,      0,      0,      1],
#        [     2, 120000,      2, ...,      0,   2000,      1],
#        [     3,  90000,      2, ...,   1000,   5000,      0],
#        ...,
#        [ 29998,  30000,      1, ...,   2000,   3100,      1],
#        [ 29999,  80000,      1, ...,  52964,   1804,      1],
#        [ 30000,  50000,      1, ...,   1000,   1000,      1]])

# %%
#Outra forma de acessar os mesmos valores acima é usando o to.numpy()

credit_renamed.to_numpy()
# Out:
# array([[     1,  20000,      2, ...,      0,      0,      1],
#        [     2, 120000,      2, ...,      0,   2000,      1],
#        [     3,  90000,      2, ...,   1000,   5000,      0],
#        ...,
#        [ 29998,  30000,      1, ...,   2000,   3100,      1],
#        [ 29999,  80000,      1, ...,  52964,   1804,      1],
#        [ 30000,  50000,      1, ...,   1000,   1000,      1]])

# %%
#Identificando o tipo de dados de cada coluna
#Saber esta informação é bom para pensar em como será o gráfico de apresentação

credit_renamed.dtypes
# Out:
# ID                            int64
# limite_credito                int64
# sexo                          int64
# nivel_escolaridade            int64
# estado_civil                  int64
# idade                         int64
# status_pag_set_2005           int64
# status_pag_ago_2005           int64
# status_pag_jul_2005           int64
# status_pag_jun_2005           int64
# status_pag_maio_2005          int64
# status_pag_abr_2005           int64
# extrato_set_2005              int64
# extrato_ago_2005              int64
# extrato_jul_2005              int64
# extrato_jun_2005              int64
# extrato_maio_2005             int64
# extrato_abr_2005              int64
# valor_pag_set_2005            int64
# valor_pag_ago_2005            int64
# valor_pag_jul_2005            int64
# valor_pag_jun_2005            int64
# valor_pag_maio_2005           int64
# valor_pag_abr_2005            int64
# default payment next month    int64
# dtype: object

# %%
#Iterando linhas e colunas de um DataFrame
#Usando estrutura de repetição para sabermos as informações de cada cliente
#Função iterrowns vai puxar as informações das linhas e colunas como uma Series

for index,row in credit_renamed.iterrows():
  print(index)
  print(row)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# valor_pag_jun_2005             2000
# valor_pag_maio_2005            1003
# valor_pag_abr_2005             1076
# default payment next month        0
# Name: 29814, dtype: int64
# 29815
# ID                             29816
# limite_credito                210000
# sexo                               1
# nivel_escolaridade                 1
# estado_civil                       2
# idade                             35
# status_pag_set_2005               -1
# status_pag_ago_2005               -1
# status_pag_jul_2005               -1
# status_pag_jun_2005               -1
# status_pag_maio_2005              -1
# status_pag_abr_2005               -1
# extrato_set_2005                 326
# extrato_ago_2005                 326
# extrato_jul_2005                 326
# extrato_jun_2005                 326
# extrato_maio_2005                326
# extrato_abr_2005                 326
# valor_pag_set_2005               326
# ...

# %% [markdown]
# 3° PASSO:
#
# * EXTRAÇÕES DE INFORMAÇÕES ESPECÍFICAS

# %% [markdown]
# Para acessar os valores de uma determinada coluna, usamos ['Nome da coluna']

# %%
credit_renamed
# Out:
#           ID  limite_credito  sexo  nivel_escolaridade  estado_civil  idade  \
# 0          1           20000     2                   2             1     24
# 1          2          120000     2                   2             2     26
# 2          3           90000     2                   2             2     34
# 3          4           50000     2                   2             1     37
# 4          5           50000     1                   2             1     57
# ...      ...             ...   ...                 ...           ...    ...
# 29995  29996          220000     1                   3             1     39
# 29996  29997          150000     1                   3             2     43
# 29997  29998           30000     1                   2             2     37
# 29998  29999           80000     1                   3             1     41
# 29999  30000           50000     1                   2             1     46
#
# ...

# %%
#Acessando UMA coluna

credit_renamed['limite_credito']
# Out:
# 0         20000
# 1        120000
# 2         90000
# 3         50000
# 4         50000
#           ...
# 29995    220000
# 29996    150000
# 29997     30000
# 29998     80000
# 29999     50000
# Name: limite_credito, Length: 30000, dtype: int64

# %% [markdown]
# * Outra forma de acessar uma linha é usando:  variável.nome_da_coluna

# %%
credit_renamed.limite_credito
# Out:
# 0         20000
# 1        120000
# 2         90000
# 3         50000
# 4         50000
#           ...
# 29995    220000
# 29996    150000
# 29997     30000
# 29998     80000
# 29999     50000
# Name: limite_credito, Length: 30000, dtype: int64

# %% [markdown]
# * É possível acessar multiplas colunas. Usando uma lista para acessar as colunas

# %%
credit_renamed[['limite_credito','nivel_escolaridade']]
# Out:
#        limite_credito  nivel_escolaridade
# 0               20000                   2
# 1              120000                   2
# 2               90000                   2
# 3               50000                   2
# 4               50000                   2
# ...               ...                 ...
# 29995          220000                   3
# 29996          150000                   3
# 29997           30000                   2
# 29998           80000                   3
# 29999           50000                   2
#
# [30000 rows x 2 columns]

# %% [markdown]
# * Outra maneira de selecionar varioas colunas é usando o método filter

# %%
#Like é usado igual em SQL, localiza todos os atributos que possuem as letras digitadas
credit_renamed.filter(like='pag')
# Out:
#        status_pag_set_2005  status_pag_ago_2005  status_pag_jul_2005  \
# 0                        2                    2                   -1
# 1                       -1                    2                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                       -1                    0                   -1
# ...                    ...                  ...                  ...
# 29995                    0                    0                    0
# 29996                   -1                   -1                   -1
# 29997                    4                    3                    2
# 29998                    1                   -1                    0
# 29999                    0                    0                    0
#
#        status_pag_jun_2005  status_pag_maio_2005  status_pag_abr_2005  \
# ...

# %% [markdown]
# * Para acessarmos linhas e grupos de linhas usamos os métodos: iloc e loc

# %%
#Para acessar UMA linha, não esquecendo de colocar o parâmetro []

credit_renamed.loc[1]
# Out:
# ID                                 2
# limite_credito                120000
# sexo                               2
# nivel_escolaridade                 2
# estado_civil                       2
# idade                             26
# status_pag_set_2005               -1
# status_pag_ago_2005                2
# status_pag_jul_2005                0
# status_pag_jun_2005                0
# status_pag_maio_2005               0
# status_pag_abr_2005                2
# extrato_set_2005                2682
# extrato_ago_2005                1725
# extrato_jul_2005                2682
# extrato_jun_2005                3272
# extrato_maio_2005               3455
# extrato_abr_2005                3261
# valor_pag_set_2005                 0
# valor_pag_ago_2005              1000
# valor_pag_jul_2005              1000
# valor_pag_jun_2005              1000
# valor_pag_maio_2005                0
# valor_pag_abr_2005              2000
# default payment next month         1
# Name: 1, dtype: int64

# %%
#Acessando MULTIPLAS linas.
#Dentro do parâmetro coloca quais linhas que deseja visualizar

credit_renamed.loc[0:2]
# Out:
#    ID  limite_credito  sexo  nivel_escolaridade  estado_civil  idade  \
# 0   1           20000     2                   2             1     24
# 1   2          120000     2                   2             2     26
# 2   3           90000     2                   2             2     34
#
#    status_pag_set_2005  status_pag_ago_2005  status_pag_jul_2005  \
# 0                    2                    2                   -1
# 1                   -1                    2                    0
# 2                    0                    0                    0
#
#    status_pag_jun_2005  ...  extrato_jun_2005  extrato_maio_2005  \
# 0                   -1  ...                 0                  0
# 1                    0  ...              3272               3455
# 2                    0  ...             14331              14948
#
#    extrato_abr_2005  valor_pag_set_2005  valor_pag_ago_2005  \
# 0                 0                   0                 689
# ...

# %%
#Acessando linhas e colunas
#Lembrando que para acessar mais de uma coluna deve-se colocar dentro de chaves
credit_renamed.loc[0:2, ['limite_credito','sexo']]
# Out:
#    limite_credito  sexo
# 0           20000     2
# 1          120000     2
# 2           90000     2

# %% [markdown]
# * loc utiliza os índices OU rótulos dos eixos das linhas e colunas como forma de endereçamento dos elementos. (nome das colunas)
#
# * iloc utiliza números inteiros correspondentes à posição dos eixos. (posição das colunas)

# %%
credit_renamed.iloc[0:4, 1:5]
# Out:
#    limite_credito  sexo  nivel_escolaridade  estado_civil
# 0           20000     2                   2             1
# 1          120000     2                   2             2
# 2           90000     2                   2             2
# 3           50000     2                   2             1

# %% [markdown]
# * Podemos também selecionar valores das linhas utilizando valores lógicos

# %%
# Acessar linhas a partir de mascaras booleanas
#para acessar o nível de uma coluna coloca-se o nome do DataFrame e a coluna desejada
credit_renamed[credit_renamed ['nivel_escolaridade'] == 2]
# Out:
#           ID  limite_credito  sexo  nivel_escolaridade  estado_civil  idade  \
# 0          1           20000     2                   2             1     24
# 1          2          120000     2                   2             2     26
# 2          3           90000     2                   2             2     34
# 3          4           50000     2                   2             1     37
# 4          5           50000     1                   2             1     57
# ...      ...             ...   ...                 ...           ...    ...
# 29990  29991          140000     1                   2             1     41
# 29991  29992          210000     1                   2             1     34
# 29994  29995           80000     1                   2             2     34
# 29997  29998           30000     1                   2             2     37
# 29999  30000           50000     1                   2             1     46
#
# ...

# %% [markdown]
# AULA 5:
#
# * ANÁLISE DE DADOS COM PANDAS I

# %% [markdown]
# PASSO 4:
#
# * ORGANIZAR E TRATAR OS DADOS

# %%
# Identificação de valores NÃO NULOS

credit_renamed.notnull()
# Out:
#          ID  limite_credito  sexo  nivel_escolaridade  estado_civil  idade  \
# 0      True            True  True                True          True   True
# 1      True            True  True                True          True   True
# 2      True            True  True                True          True   True
# 3      True            True  True                True          True   True
# 4      True            True  True                True          True   True
# ...     ...             ...   ...                 ...           ...    ...
# 29995  True            True  True                True          True   True
# 29996  True            True  True                True          True   True
# 29997  True            True  True                True          True   True
# 29998  True            True  True                True          True   True
# 29999  True            True  True                True          True   True
#
# ...

# %%
#Identificação de valores NULOS

credit_renamed.isnull()
# Out:
#           ID  limite_credito   sexo  nivel_escolaridade  estado_civil  idade  \
# 0      False           False  False               False         False  False
# 1      False           False  False               False         False  False
# 2      False           False  False               False         False  False
# 3      False           False  False               False         False  False
# 4      False           False  False               False         False  False
# ...      ...             ...    ...                 ...           ...    ...
# 29995  False           False  False               False         False  False
# 29996  False           False  False               False         False  False
# 29997  False           False  False               False         False  False
# 29998  False           False  False               False         False  False
# 29999  False           False  False               False         False  False
#
# ...

# %%
# Somando os valores NULOS
# Os valores que aparecerão, são nulos em cada coluna

credit_renamed.isnull().sum()
# Out:
# ID                            0
# limite_credito                0
# sexo                          0
# nivel_escolaridade            0
# estado_civil                  0
# idade                         0
# status_pag_set_2005           0
# status_pag_ago_2005           0
# status_pag_jul_2005           0
# status_pag_jun_2005           0
# status_pag_maio_2005          0
# status_pag_abr_2005           0
# extrato_set_2005              0
# extrato_ago_2005              0
# extrato_jul_2005              0
# extrato_jun_2005              0
# extrato_maio_2005             0
# extrato_abr_2005              0
# valor_pag_set_2005            0
# valor_pag_ago_2005            0
# valor_pag_jul_2005            0
# valor_pag_jun_2005            0
# valor_pag_maio_2005           0
# valor_pag_abr_2005            0
# default payment next month    0
# dtype: int64

# %%
# Filtrando os valores nulos. Se houver valores nulos aparecerão as linhas correspondentes aos valores.

credit_renamed[credit_renamed['ID'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, limite_credito, sexo, nivel_escolaridade, estado_civil, idade, status_pag_set_2005, status_pag_ago_2005, status_pag_jul_2005, status_pag_jun_2005, status_pag_maio_2005, status_pag_abr_2005, extrato_set_2005, extrato_ago_2005, extrato_jul_2005, extrato_jun_2005, extrato_maio_2005, extrato_abr_2005, valor_pag_set_2005, valor_pag_ago_2005, valor_pag_jul_2005, valor_pag_jun_2005, valor_pag_maio_2005, valor_pag_abr_2005, default payment next month]
# Index: []
#
# [0 rows x 25 columns]

# %%
#Excluir as linhas com valores NULOS. Há duas formas

# notna()

credit2 = credit_renamed[credit_renamed['ID'].notna()] 
### é sempre bom criara uma nova variável para não perder as informações contidas no DataFrame original; assim fazendo uma comparação

# %%
#Outra função para excluir valores NULOS é:
# dropna()

credit3 = credit_renamed.dropna(how=all)

#para esta função há duas formas de exclusão.
#all: elimina se toda a linha estiver NULOS.
#any: elimina a linha se houver apenas um número NULO.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-50973b118b1a> in <module>
#       2 # dropna()
#       3
# ----> 4 credit3 = credit_renamed.dropna(how=all)
#       5
#       6 #para esta função há duas formas de exclusão.
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5964         else:
#    5965             if how is not None:
# -> 5966                 raise ValueError(f"invalid how option: {how}")
#    5967             else:
#    5968                 raise TypeError("must specify how or thresh")
#
# ...

# %% [markdown]
# * REMOVENDO DUPLICATAS

# %% [markdown]
# * Observação
#
# O método drop_duplicates() ajuda a remover duplicatas do DataFrame. Recebe os seguintes parâmetros:
#
# subset: especifica uma coluna ou lista de rótulos de colunas. Valor padrão None.
#
# keep: serve para controlar o que considerar como valor duplicado:
#
# * first: descarta duplicatas, exceto a primeira ocorrência.
#
# * last: descarta duplicatas, exceto a última ocorrência.
#
# * False: elimina todas as duplicatas.
#
# inplace: valores booleanos, remove as linhas como duplicatas se True.

# %%
#Removendo duplicatas com a função:
#drop_duplicates()

credit_renamed.drop_duplicates(subset='ID', keep = 'first', inplace = True)

# %%
credit_renamed
# Out:
#           ID  limite_credito  sexo  nivel_escolaridade  estado_civil  idade  \
# 0          1           20000     2                   2             1     24
# 1          2          120000     2                   2             2     26
# 2          3           90000     2                   2             2     34
# 3          4           50000     2                   2             1     37
# 4          5           50000     1                   2             1     57
# ...      ...             ...   ...                 ...           ...    ...
# 29995  29996          220000     1                   3             1     39
# 29996  29997          150000     1                   3             2     43
# 29997  29998           30000     1                   2             2     37
# 29998  29999           80000     1                   3             1     41
# 29999  30000           50000     1                   2             1     46
#
# ...

# %%
#Agrupando valores
#groupby

credit_grouped = credit_renamed.groupby('nivel_escolaridade').mean().reset_index()
credit_grouped
# Out:
#    nivel_escolaridade            ID  limite_credito      sexo  estado_civil  \
# 0                   0  17091.357143   217142.857143  1.428571      1.714286
# 1                   1  14697.212187   212956.069910  1.588663      1.652338
# 2                   2  15024.237776   147062.437634  1.616964      1.523022
# 3                   3  15342.314013   126550.270490  1.595282      1.421192
# 4                   4  18143.447154   220894.308943  1.658537      1.601626
# 5                   5  17443.664286   168164.285714  1.660714      1.475000
# 6                   6  16895.019608   148235.294118  1.509804      1.490196
#
#        idade  status_pag_set_2005  status_pag_ago_2005  status_pag_jul_2005  \
# 0  38.857143            -0.500000            -1.000000            -0.928571
# 1  34.231838            -0.233916            -0.408125            -0.425886
# 2  34.722096             0.102210             0.022523            -0.018532
# ...

# %% [markdown]
# AULA 6:
#
# * ANÁLISE DE DADOS COM PANDAS II

# %% [markdown]
# ENTENDENDO AS PRINCIPAIS ESTATISTICAS DESCRITIVAS

# %% [markdown]
# PASSO 5:
#
# * Análises exploratórias e extração de atributos

# %%
#Extraindo um sumário das estatísticas descritivas
#describe() só mostra a estatística de colunas numéricas.

credit_renamed.describe()
# Out:
#                  ID  limite_credito          sexo  nivel_escolaridade  \
# count  30000.000000    30000.000000  30000.000000        30000.000000
# mean   15000.500000   167484.322667      1.603733            1.853133
# std     8660.398374   129747.661567      0.489129            0.790349
# min        1.000000    10000.000000      1.000000            0.000000
# 25%     7500.750000    50000.000000      1.000000            1.000000
# 50%    15000.500000   140000.000000      2.000000            2.000000
# 75%    22500.250000   240000.000000      2.000000            2.000000
# max    30000.000000  1000000.000000      2.000000            6.000000
#
#        estado_civil         idade  status_pag_set_2005  status_pag_ago_2005  \
# count  30000.000000  30000.000000         30000.000000         30000.000000
# mean       1.551867     35.485500            -0.016700            -0.133767
# std        0.521970      9.217904             1.123802             1.197186
# ...

# %% [markdown]
# GRÁFICO DE BARRA MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
#Primeiro passo, construção da figura
plt.figure(figsize=(10, 5))

#Incluir o título do gráfico

plt.title('Credito concedido segundo escolaridade')

#Colocando títulos nos eixos

plt.xlabel('Nível de escolaridade')
plt.ylabel('Limite de crédito')

#Criando o gráfico em forma de barra

plt.bar(credit_grouped['nivel_escolaridade'],
        credit_grouped['limite_credito']);

# %% [markdown]
# GRÁFICO DE BARRAS COM SEABORN

# %%
#Extrato bancário dos clientes segundo o nível de escolaridade  para os últimos 4 meses
#Algumas funções da seaborn não existem especificas nessa biblioteca. tendo que puxar da matplotlib
# A seaborn não tem função específica para subplot

#Primeiro passo construção da figura
fig, axes = plt.subplots(2, 2, figsize= (20, 15))

#Criando gráfico de barras com seaborn

sns.barplot(data= credit_grouped, x='nivel_escolaridade', y='extrato_jun_2005', ax=axes[0,0])
sns.barplot(data= credit_grouped, x='nivel_escolaridade', y='extrato_jul_2005', ax=axes[0,1])
sns.barplot(data= credit_grouped, x='nivel_escolaridade', y='extrato_ago_2005', ax=axes[1,0])
sns.barplot(data= credit_grouped, x='nivel_escolaridade', y='extrato_set_2005', ax=axes[1,1]);

# %% [markdown]
# GRÁFICOS DE BARRAS COM PLOTLY

# %%
#Primeiro passo, construção da figura
# Nesta biblioteca a legenda lateral é inclusa automáticamente e é interativa

fig = go.Figure()

#add escolhe o tipo de gráfico que será feito (barra, linha etc)

#mark_color='' serve para escolher a cor da barra, para diferenciar os meses
fig.add_trace(go.Bar(x=credit_grouped['nivel_escolaridade'],
                     y=credit_grouped['valor_pag_abr_2005'],
                     marker_color='Red',
                     name='Valor pago 04/2005' ))

fig.add_trace(go.Bar(x=credit_grouped['nivel_escolaridade'],
                     y=credit_grouped['valor_pag_maio_2005'],
                     marker_color='Blue',
                     name='Valor pago 05/2005' ))

fig.add_trace(go.Bar(x=credit_grouped['nivel_escolaridade'],
                     y=credit_grouped['valor_pag_jun_2005'],
                     marker_color='Green',
                     name='Valor pago 06/2005' ))

fig.add_trace(go.Bar(x=credit_grouped['nivel_escolaridade'],
                     y=credit_grouped['valor_pag_jul_2005'],
                     marker_color='Purple',
                     name='Valor pago 07/2005' ))

fig.add_trace(go.Bar(x=credit_grouped['nivel_escolaridade'],
                     y=credit_grouped['valor_pag_ago_2005'],
                     marker_color='Yellow',
                     name='Valor pago 08/2005' ))

fig.add_trace(go.Bar(x=credit_grouped['nivel_escolaridade'],
                     y=credit_grouped['valor_pag_set_2005'],
                     marker_color='Orange',
                     name='Valor pago 09/2005' ))

#Nome do eixo
#tickfont é o tamanho do tickt que aparece as laterais e abaixo do gráfico

fig.update_layout(yaxis= dict(title='Valor de Pagamento em 2005 ',
                              titlefont_size= 15,
                              tickfont_size=10 ),
                  xaxis= dict(title='Nível de escolaridade',
                              titlefont_size= 15,
                              tickfont_size=10 ))

#Salvando gráfico interativo

fig.write_html('Valor_pago_escolaridade.html')

# %%
#Apresentar o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * GRTÁFICO DE LINHAS
#
#   * MATPLOTLIB
#
#   * seaborn
#
#   * plotly
#
# * Objetivo: Apresentar um panorama consolidado sobre a situação dos clientes no banco para o restante da empresa.
#
# * objetivo específico: Analisar a situação dos cliente( valor de crédito concedido, valor pago e extrato), nos últimos meses para o ano de 2005 de acordo com a idade

# %% [markdown]
# MATPLOTLIB

# %%
#buscando dados de acordo com a idade

credit_grouped = credit_renamed.groupby(['idade']).mean().reset_index()
credit_grouped
# Out:
#     idade            ID  limite_credito      sexo  nivel_escolaridade  \
# 0      21  13814.104478    23283.582090  1.686567            2.104478
# 1      22  13799.010714    37928.571429  1.751786            1.969643
# 2      23  14262.792696    59752.953813  1.720730            1.888292
# 3      24  14150.837622    75661.047028  1.685004            1.842059
# 4      25  14541.063238   102731.871838  1.671164            1.779933
# 5      26  14593.886943   128813.694268  1.630573            1.773885
# 6      27  14975.387271   147941.773866  1.641842            1.689912
# 7      28  15146.515969   170943.931867  1.640880            1.664301
# 8      29  14927.917757   179401.869159  1.615576            1.621184
# 9      30  15159.384946   189591.397849  1.597849            1.689606
# 10     31  15677.135579   193755.135579  1.603122            1.674610
# 11     32  15176.025907   200397.236615  1.588946            1.719344
# ...

# %%
#Criando gráfico de linha de acordo com os dados acima

plt.figure(figsize=(10,8))

plt.title('Limite de crédito concedido conforme idade')

plt.xlabel('Idade')
plt.ylabel('Média do valor de crédito concedido')

plt.plot(credit_grouped['idade'], credit_grouped['limite_credito']);


#adicionando um grid de fundo

plt.grid(b=True, linewidth=0.5)

# %% [markdown]
# SEABORN
#   * Estrato bancário

# %%
credit_grouped
# Out:
#     idade            ID  limite_credito      sexo  nivel_escolaridade  \
# 0      21  13814.104478    23283.582090  1.686567            2.104478
# 1      22  13799.010714    37928.571429  1.751786            1.969643
# 2      23  14262.792696    59752.953813  1.720730            1.888292
# 3      24  14150.837622    75661.047028  1.685004            1.842059
# 4      25  14541.063238   102731.871838  1.671164            1.779933
# 5      26  14593.886943   128813.694268  1.630573            1.773885
# 6      27  14975.387271   147941.773866  1.641842            1.689912
# 7      28  15146.515969   170943.931867  1.640880            1.664301
# 8      29  14927.917757   179401.869159  1.615576            1.621184
# 9      30  15159.384946   189591.397849  1.597849            1.689606
# 10     31  15677.135579   193755.135579  1.603122            1.674610
# 11     32  15176.025907   200397.236615  1.588946            1.719344
# ...

# %%
#Definindo um subplot em seaborn

fig, axes = plt.subplots(2,2, figsize=(20,10))

sns.lineplot(data=credit_renamed, x='idade', y='extrato_jun_2005', hue='sexo', style='sexo', palette='Set2', ax=axes[0,0]).set(title='Extrato em Junho de 2005', xlabel=None);
sns.lineplot(data=credit_renamed, x='idade', y='extrato_jul_2005', hue='sexo', style='sexo', palette='Set2',  ax=axes[0,1]).set(title='Extrato em Julho de 2005', xlabel=None);
sns.lineplot(data=credit_renamed, x='idade', y='extrato_ago_2005', hue='sexo', style='sexo', palette='Set2',  ax=axes[1,0]).set(title='Extrato em Agosto de 2005');
sns.lineplot(data=credit_renamed, x='idade', y='extrato_set_2005', hue='sexo', style='sexo', palette='Set2',  ax=axes[1,1]).set(title='Extrato em Setembro de 2005');

#hue='', faz com que apareça a diferença entre os sexos
#1 = Masculino
#2 = Feminino

#style diferencia as linhas no sexo
#palette escolhe a palheta de cores da linha

# %% [markdown]
# GRÁFICO DE LINHA PLOTLY
#
#   * Valor Pago

# %%
#Valor pago ao longo dos meses de acordo com a idade
#shared_yaxes=True,  indica se as linha irão compartilhar o mesmo eixo y
#rows = linhas, cols = colunas

fig = go.Figure()

from plotly.subplots import make_subplots

fig = make_subplots(rows= 3, cols=2, shared_yaxes=True, 
                   subplot_titles=('Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro'))

#Gráfico de linha em plotly

fig.add_trace(go.Scatter(x = credit_grouped['idade'],
                         y = credit_grouped['valor_pag_abr_2005'],
                         line=dict(color='Red', width=1.5),
                         name='Valor pago 04/2005'), row = 1, col = 1,)

fig.add_trace(go.Scatter(x = credit_grouped['idade'],
                         y = credit_grouped['valor_pag_maio_2005'],
                         line=dict(color='Blue', width=1.5),
                         name='Valor pago 05/2005'),row = 1 , col = 2)

fig.add_trace(go.Scatter(x = credit_grouped['idade'],
                         y = credit_grouped['valor_pag_jun_2005'],
                         line=dict(color='Green', width=1.5),
                         name='Valor pago 06/2005'), row = 2 , col= 1)

fig.add_trace(go.Scatter(x = credit_grouped['idade'],
                         y = credit_grouped['valor_pag_jul_2005'],
                         line=dict(color='Yellow', width=1.5), 
                         name= 'Valor pago 07/2005'), row = 2, col = 2)

fig.add_trace(go.Scatter(x = credit_grouped['idade'],
                         y = credit_grouped['valor_pag_ago_2005'],
                         line=dict(color='Grey'),
                         name='Valor pago 08/2005'), row = 3, col = 1)

fig.add_trace(go.Scatter(x = credit_grouped['idade'],
                         y = credit_grouped['valor_pag_set_2005'],
                         line=dict(color='black', width=1.5), 
                         name= 'Valor pago 09/2005'), row =3 , col = 2)

fig.update_layout(title_text= 'Valor pago ao longo de 2005 de acordo com idade dos cliente')

fig.update_yaxes(title_text = 'Valor pago (Dollar NT)', row = 1, col = 1, titlefont_size = 8)
fig.update_yaxes(title_text = 'Valor pago (Dollar NT)', row = 1, col = 2, titlefont_size = 8)
fig.update_yaxes(title_text = 'Valor pago (Dollar NT)', row = 2, col = 1, titlefont_size = 8)
fig.update_yaxes(title_text = 'Valor pago (Dollar NT)', row = 2, col = 2, titlefont_size = 8)
fig.update_yaxes(title_text = 'Valor pago (Dollar NT)', row = 3, col = 1, titlefont_size = 8)
fig.update_yaxes(title_text = 'Valor pago (Dollar NT)', row = 3, col = 2, titlefont_size = 8)

fig.update_xaxes( row = 1, col = 1, titlefont_size = 8)
fig.update_xaxes(row = 1, col = 2, titlefont_size = 8)
fig.update_xaxes(row = 2, col = 1, titlefont_size = 8)
fig.update_xaxes(row = 2, col = 2, titlefont_size = 8)
fig.update_xaxes(title_text = 'Idade', row = 3, col = 1, titlefont_size = 8)
fig.update_xaxes(title_text = 'Idade', row = 3, col = 2, titlefont_size = 8)

fig.show()

#Salvando gráfico interátivo

fig.write_html('valor_pago_idade_html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# VISUALIZAÇÃO DE DADOS
#
#   * OUTROS EXEMPLOS

# %% [markdown]
# Matplotlib, Seaborn, Plotly

# %%
#Gráfico com MATPLOTLIB - plotagem de funções matemáticas (interação com numpy)

#criar uma matrix com a função linspace da numpy

t = np.linspace(0.0, 2, 100)


#Criando outras duas matrizes com diferentes funções trigonométricas

f1 = np.sin(np.pi * t)
f2 = np.sin(2 * np.pi * t)

plt.figure(figsize=(10, 8))

plt.plot(t, f1, label = 'Seno de pi * T')
plt.plot(t, f2, label = '2 Seno de pi * T')

plt.legend()

plt.title('Senoides')

plt.grid(b=True, linewidth= 0.5, color='Grey')

# %% [markdown]
#   * Seaborn

# %%
#Diagrama de correlação

#Objetivo: situação dos cliente do banco e apresentar um panorama para a empresa.


credit_renamed

plt.figure(figsize=(20,20))

#mapa de calor - Correlação através das cores
#cmap - escolha do gradiente
#annot = True - mostra os valores de correlação

sns.heatmap(credit_renamed.corr(), annot = True, cmap= 'coolwarm');
